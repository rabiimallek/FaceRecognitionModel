# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
dossier=os.listdir("/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme_Aug2/Femme")
len(dossier)
# Out:
# 10107

# %%
import os
dossier=os.listdir("/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme_Aug2/Homme")
len(dossier)
# Out:
# 10107

# %%
"""
import os
import random
from PIL import Image, ImageOps

# définir le chemin vers le dossier contenant les sous-dossiers
folder_path = '/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme'

# définir le chemin vers le dossier où les images augmentées seront stockées
augmented_folder_path = '/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme_Aug2'

# créer le dossier s'il n'existe pas déjà
if not os.path.exists(augmented_folder_path):
    os.mkdir(augmented_folder_path)

# itérer sur les sous-dossiers
for subdir in os.listdir(folder_path):
    subdir_path = os.path.join(folder_path, subdir)
    if os.path.isdir(subdir_path):
        # créer le sous-dossier correspondant dans le dossier augmenté
        augmented_subdir_path = os.path.join(augmented_folder_path, subdir)
        if not os.path.exists(augmented_subdir_path):
            os.mkdir(augmented_subdir_path)

        # récupérer la liste des fichiers d'image dans le sous-dossier
        image_files = [f for f in os.listdir(subdir_path) if f.endswith('.jpg')or ('.png')]

        # calculer le nombre d'images à créer pour atteindre le total de 18
        num_images = 10107- len(image_files)

        # itérer sur le nombre d'images à créer
        for i in range(num_images):
            # choisir une image aléatoire dans le sous-dossier
            image_file = random.choice(image_files)
            image_path = os.path.join(subdir_path, image_file)

            # ouvrir l'image
            with Image.open(image_path) as img:
                # Appliquer une augmentation de données aléatoire
                method = random.choice(['horizontal_flip', 'vertical_flip', 'rotate'])
                if method == 'horizontal_flip':
                    img = img.transpose(method=Image.FLIP_LEFT_RIGHT)
                elif method == 'vertical_flip':
                    img = img.transpose(method=Image.FLIP_TOP_BOTTOM)
                elif method == 'rotate':
                    degrees = random.randint(-20, 20)
                   

                # sauvegarder l'image augmentée dans le dossier correspondant
                new_image_name = os.path.splitext(image_file)[0] + '_augmented_' + str(i) + os.path.splitext(image_file)[1]
                new_image_path = os.path.join(augmented_subdir_path, new_image_name)
                img.save(new_image_path)
"""

# %%
"""
import os
import shutil

# Chemin du dossier source
src_folder = '/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme/Homme'

# Chemin du dossier destination
dst_folder = '/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme_Aug2/Homme'

# Liste des fichiers dans le dossier source
files = os.listdir(src_folder)

# Boucle sur tous les fichiers du dossier source
for file_name in files:
    # Vérifie si le fichier a l'extension .jpg
    if file_name.endswith('.jpg'):
        # Chemin complet du fichier source
        src_file = os.path.join(src_folder, file_name)
        # Chemin complet du fichier destination
        dst_file = os.path.join(dst_folder, file_name)
        # Copie du fichier source vers le dossier destination
        shutil.copy(src_file, dst_file)
"""

# %%
import cv2 
import numpy as np
import os

# %%
dossier=os.listdir("/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme_Aug2/Femme")
Femme=np.zeros((len(dossier),64,64,3))
Labels_F=[]
for i in range(len(dossier)):
  nom_image='/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme_Aug2/Femme/'+dossier[i]
  image = cv2.resize((cv2.imread(nom_image)), (64,64))
  Femme[i]=image
  Labels_F.append(0)

# %%
dossier1=os.listdir("/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme_Aug2/Homme")
Homme=np.zeros((len(dossier1),64,64,3))
Labels_H=[]
for i in range(len(dossier1)):
  nom_image='/content/drive/MyDrive/Adience_Aug2_Gender_Recognition/Adience_Homme_Femme_Aug2/Homme/'+dossier1[i]
  image = cv2.resize((cv2.imread(nom_image)), (64,64))
  Homme[i]=image
  Labels_H.append(1)

# %%
def train (x):
  return int(x*0.8)

# %%
images_train_Homme=Homme[:train(len(Homme))]
images_test_Homme=Homme[train(len(Homme)):]
labels_train_Homme=Labels_H[:train(len(Labels_H))]
labels_test_Homme=Labels_H[train(len(Labels_H)):]

images_train_Femme=Femme[:train(len(Femme))]
images_test_Femme=Femme[train(len(Femme)):]
labels_train_Femme=Labels_F[:train(len(Labels_F))]
labels_test_Femme=Labels_F[train(len(Labels_F)):]

# %%
X_train=np.concatenate((images_train_Homme,images_train_Femme),axis=0)
Y_train=np.concatenate((labels_train_Homme,labels_train_Femme),axis=0)
X_test=np.concatenate((images_test_Homme,images_test_Femme),axis=0)
Y_test=np.concatenate((labels_test_Homme,labels_test_Femme),axis=0)

# %%
print(len(X_train))
print(len(Y_train))
print(len(X_test))
print(len(Y_test))
# Out:
# 16170
# 16170
# 4044
# 4044

# %%
pip install keras-facenet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.7 MB/s eta 0:00:00
# ...
#   Created wheel for keras-facenet: filename=keras_facenet-0.3.2-py3-none-any.whl size=10385 sha256=d7e89ade1416293d10212ea415ccd5becb515ecf6bb76fdd13394113385f5554
#   Stored in directory: /root/.cache/pip/wheels/1d/d8/a9/85cf04ea29321d2afcb82c0caaafdca9195385f9d68cbc7185
# Successfully built keras-facenet
# ...

# %%
from keras_facenet import FaceNet

# %%
model = FaceNet()

# %%
def get_embedding(model, face):
    # transfer face into one sample (3 dimension to 4 dimension):ajoute une dimension supplémentaire à l'image du visage
    #afin qu'elle puisse être transmise à travers le modèle. (4 dim: 1:taille de lot , 3: H,L, canaux de l'image)
    sample = np.expand_dims(face, axis=0) 
    # make prediction to get embedding:passe le sample tableau à travers la embeddings méthode du model
    #pour générer l'incorporation de l'image du visage.
    yhat = model.embeddings(sample)
    return yhat[0]#renvoie l'intégration sous la forme d'un tableau NumPy unidimensionnel.

# %%
# convert each face in the train set into embedding
emdTrainX = list()
for face in X_train:
    emd = get_embedding(model,face)
    emdTrainX.append(emd)
    
emdTrainX = np.asarray(emdTrainX)
print(emdTrainX.shape)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# ...
# 1/1 [==============================] - 0s 189ms/step
# ...
# ...
# 1/1 [==============================] - 0s 110ms/step
# (16170, 512)

# %%
# convert each face in the test set into embedding
emdTestX = list()
for face in X_test:
    emd = get_embedding(model, face)
    emdTestX.append(emd)
emdTestX = np.asarray(emdTestX)
print(emdTestX.shape)
# Out:
# ...
# 1/1 [==============================] - 0s 159ms/step
# ...
# ...
# 1/1 [==============================] - 0s 122ms/step
# (4044, 512)

# %%
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.svm import SVC

print("Dataset: train=%d, test=%d" % (emdTrainX.shape[0], emdTestX.shape[0]))
# normalize input vectors
in_encoder = Normalizer()
emdTrainX_norm = in_encoder.transform(emdTrainX)
emdTestX_norm = in_encoder.transform(emdTestX)
# Out:
# Dataset: train=16170, test=4044

# %%
# label encode targets
#un encodage des étiquettes (labels)
out_encoder = LabelEncoder()#transforme des étiquettes de texte (ou de catégories) en entiers.
out_encoder.fit(Y_train)#calcule les correspondances entre les étiquettes et les entiers
trainy_enc = out_encoder.transform(Y_train)#applique ces correspondances à la variable d'entrée et renvoie les entiers correspondants.
testy_enc = out_encoder.transform(Y_test)

# %%
# fit model
model = SVC(kernel='rbf',degree=3, gamma=1,probability=True,C=100 )
model.fit(emdTrainX_norm, trainy_enc)
# predict
#prédiction des classes sur data train & test à l'aide d'un modèle de classification
yhat_train = model.predict(emdTrainX_norm)
yhat_test = model.predict(emdTestX_norm)


# score:calcule la précision de la prédiction pour chaque ensemble.
score_train = accuracy_score(trainy_enc, yhat_train)
score_test = accuracy_score(testy_enc, yhat_test)
# summarize
print('Accuracy: train=%.3f, test=%.3f' % (score_train*100, score_test*100))
# Out:
# Accuracy: train=99.907, test=89.095

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
res = confusion_matrix(testy_enc, yhat_test)
for i in range(0,len(res)):
  print(res[i])
print("Confusion Matrix")
print(res)
print(f"Test Set: {len(Y_test)}")
print(f"Accuracy = {score_test*100} %")
print(classification_report(testy_enc, yhat_test))
# Out:
# [1752  270]
# [ 171 1851]
# Confusion Matrix
# [[1752  270]
#  [ 171 1851]]
# Test Set: 4044
# Accuracy = 89.09495548961425 %
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      2022
#            1       0.87      0.92      0.89      2022
#
#     accuracy                           0.89      4044
#    macro avg       0.89      0.89      0.89      4044
# weighted avg       0.89      0.89      0.89      4044
